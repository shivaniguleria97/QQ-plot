# %% [markdown]
# <a href="https://colab.research.google.com/github/shivaniguleria97/QQ-plot/blob/main/NumPy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
r=np.arange(10)
print(r)

# %%
s=np.arange(1,30)
print(s)

# %%
a=np.linspace(1,30,10)
print(a)

# %%
s.reshape(5,2)

# %%
a.reshape(5,-1)

# %%
m=np.arange(1,21).reshape(5,-1)
print(m)

# %%
print(s)

# %%
s[2:5]

# %%
print(m)

# %%
m[1:5,2:5]
